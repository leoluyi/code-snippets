# %% [markdown]
# # Python - Pillow PIL image processing
#
# http://pillow.readthedocs.io/en/3.1.x/handbook/concepts.html

# %%
from PIL import Image

# %matplotlib inline

# %% [markdown]
# ## Filter colors

# %%
im = Image.open('img/stamped.jpg')
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=579x581 at 0x10810C908>

# %%
pixels = im.load()

for x in range(im.width):
    for y in range(im.height):
        r, g, b = im.getpixel( (x, y) )
        if not b * 1.9 > (r + g):
            pixels[x, y] = (255, 255, 255)
                        
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=579x581 at 0x10D6DA860>

# %% [markdown]
# ## Play with colors

# %%
# PIL accesses images in Cartesian co-ordinates, so it is Image[columns, rows]

img = Image.new(mode='RGB', size=(250, 250), color="black") # create a new black image
img
# Out:
# <PIL.Image.Image image mode=RGB size=250x250 at 0x1098B0390>

# %%
pixels = img.load() # create the pixel map

for i in range(img.size[0]):    # for every col:
    for j in range(img.size[1]):    # for every row
        pixels[i,j] = (i, j, 100) # set the colour accordingly

img
# Out:
# <PIL.Image.Image image mode=RGB size=250x250 at 0x1098B0390>
